# %% [markdown]
# ## INITIAL DATA EXPLORATION

# %%
#TO DISPLAY FIRST FEW RECORDS
uber_df.head()
# Out:
#          Date      Time Booking ID       Booking Status Customer ID  \
# 0  2025-01-12  15:44:00  UBR100294  Cancelled by Driver    CUST1016
# 1  2025-03-12  05:17:00  UBR100453            Completed    CUST1040
# 2  2025-01-13  11:35:00  UBR100638            Completed    CUST1004
# 3  2025-05-22  08:00:00  UBR100139  Cancelled by Driver    CUST1150
# 4  2025-01-20  11:30:00  UBR100804            Completed    CUST1077
#
#    Vehicle Type Pickup Location Drop Location  waiting time  Avg CTAT  ...  \
# 0        UberXL             NaN     Melbourne           NaN       4.9  ...
# 1    Uber Black     Los Angeles        Madrid          11.3       4.9  ...
# 2  Uber Comfort       Melbourne         Dubai           3.7      18.2  ...
# 3        UberXL      Birmingham    Manchester           6.8      11.4  ...
# 4    Uber Green           Paris         Dubai          10.2      24.3  ...
#
#    Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...

# %%
#TO DISPLAY LAST FEW ROWS
uber_df.tail()
# Out:
#             Date      Time Booking ID         Booking Status Customer ID  \
# 1030  2025-06-02  23:40:00  UBR100087              Completed    CUST1209
# 1031  2025-01-02  14:03:00  UBR100330              Completed    CUST1120
# 1032  2025-02-20  03:29:00  UBR100620  Cancelled by Customer    CUST1125
# 1033  2025-06-24  20:16:00  UBR100121              Completed    CUST1054
# 1034  2025-05-20  10:05:00  UBR100860    Cancelled by Driver    CUST1219
#
#       Vehicle Type Pickup Location Drop Location  waiting time  Avg CTAT  ...  \
# 1030         UberX            Rome    Manchester          16.1      16.5  ...
# 1031        UberXL          Madrid     Vancouver          16.8       7.7  ...
# 1032  Uber Comfort         Chicago    Birmingham          11.1      21.2  ...
# 1033        UberXL        New York         Paris           7.4       3.4  ...
# 1034    Uber Black        New York          Rome           8.3      24.5  ...
#
# ...

# %%
#DIMENSION OF THE DATASET (NUMBER OF ROWS & NUMBER OF COLUMNS)
uber_df.shape
# Out:
# (1035, 21)

# %%
#QUICK OVERVIEW OF THE DATAFRAME
uber_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               1035 non-null   str
#  1   Time                               1035 non-null   str
#  2   Booking ID                         1035 non-null   str
#  3   Booking Status                     1035 non-null   str
#  4   Customer ID                        1014 non-null   str
#  5   Vehicle Type                       1020 non-null   str
#  6   Pickup Location                    1019 non-null   str
#  7   Drop Location                      1020 non-null   str
#  8   waiting time                       994 non-null    float64
#  9   Avg CTAT                           1004 non-null   float64
#  10  Cancelled Rides by Customer        1035 non-null   int64
#  11  Reason for cancelling by Customer  94 non-null     str
# ...

# %%
#SIZE OF DATAFRAME : TOTAL NUMBER OF ROWS AND COLUMNS
uber_df.size
# Out:
# 21735

# %%
#TO DISPLAY ALL THE COLUMN NAMES PRESENT IN DATAFRAME
uber_df.columns
# Out:
# Index(['Date', 'Time', 'Booking ID', 'Booking Status', 'Customer ID',
#        'Vehicle Type', 'Pickup Location', 'Drop Location', 'waiting time',
#        'Avg CTAT', 'Cancelled Rides by Customer',
#        'Reason for cancelling by Customer', 'Cancelled Rides by Driver',
#        'Driver Cancellation Reason', 'Incomplete Rides',
#        'Incomplete Rides Reason', 'Booking Value', 'Ride Distance',
#        'Driver Ratings', 'Customer Rating', 'Payment Method'],
#       dtype='str')

# %%
#TO RETRIVE/ DISPLAY COLUMN NAME BASED ON INDEX
uber_df.columns[10]
# Out:
# 'Cancelled Rides by Customer'

# %%
# TO CONVERT DATAFRAME COLUMNS (INDEX) INTO A LIST
list(uber_df.columns)
# Out:
# ['Date',
#  'Time',
#  'Booking ID',
#  'Booking Status',
#  'Customer ID',
#  'Vehicle Type',
#  'Pickup Location',
#  'Drop Location',
#  'waiting time',
#  'Avg CTAT',
#  'Cancelled Rides by Customer',
#  'Reason for cancelling by Customer',
#  'Cancelled Rides by Driver',
#  'Driver Cancellation Reason',
#  'Incomplete Rides',
#  'Incomplete Rides Reason',
#  'Booking Value',
#  'Ride Distance',
#  'Driver Ratings',
#  'Customer Rating',
#  'Payment Method']

# %%
#TO DISPLAY DATATYPES OF EACH COLUMNS PRESENT IN DATAFRAME
uber_df.dtypes
# Out:
# Date                                     str
# Time                                     str
# Booking ID                               str
# Booking Status                           str
# Customer ID                              str
# Vehicle Type                             str
# Pickup Location                          str
# Drop Location                            str
# waiting time                         float64
# Avg CTAT                             float64
# Cancelled Rides by Customer            int64
# Reason for cancelling by Customer        str
# Cancelled Rides by Driver              int64
# Driver Cancellation Reason               str
# Incomplete Rides                       int64
# Incomplete Rides Reason                  str
# Booking Value                        float64
# Ride Distance                        float64
# Driver Ratings                       float64
# Customer Rating                      float64
# Payment Method                           str
# ...

# %%
#TO SELECT & DISPLAY PARTICULAR DATATYPE COLUMNS
uber_df.select_dtypes(include=['float64'])   #TO SELECT DATA TYPE: float64
# Out:
#       waiting time  Avg CTAT  Booking Value  Ride Distance  Driver Ratings  \
# 0              NaN       4.9           0.00          12.95             2.5
# 1             11.3       4.9          79.67          22.87             3.7
# 2              3.7      18.2         124.67          32.51             3.1
# 3              6.8      11.4           0.00          29.12             NaN
# 4             10.2      24.3          56.68          25.32             2.9
# ...            ...       ...            ...            ...             ...
# 1030          16.1      16.5          68.48          19.43             1.9
# 1031          16.8       7.7          25.74          10.14             2.7
# 1032          11.1      21.2           0.00          16.04             NaN
# 1033           7.4       3.4          37.92           9.13             2.0
# 1034           8.3      24.5           0.00          33.46             1.4
#
#       Customer Rating
# 0                 NaN
# ...

# %%
#TO SELECT & DISPLAY PARTICULAR DATATYPE COLUMNS
uber_df.select_dtypes(include=['str'])   #TO SELECT DATA TYPE: str
# Out:
#             Date      Time Booking ID         Booking Status Customer ID  \
# 0     2025-01-12  15:44:00  UBR100294    Cancelled by Driver    CUST1016
# 1     2025-03-12  05:17:00  UBR100453              Completed    CUST1040
# 2     2025-01-13  11:35:00  UBR100638              Completed    CUST1004
# 3     2025-05-22  08:00:00  UBR100139    Cancelled by Driver    CUST1150
# 4     2025-01-20  11:30:00  UBR100804              Completed    CUST1077
# ...          ...       ...        ...                    ...         ...
# 1030  2025-06-02  23:40:00  UBR100087              Completed    CUST1209
# 1031  2025-01-02  14:03:00  UBR100330              Completed    CUST1120
# 1032  2025-02-20  03:29:00  UBR100620  Cancelled by Customer    CUST1125
# 1033  2025-06-24  20:16:00  UBR100121              Completed    CUST1054
# 1034  2025-05-20  10:05:00  UBR100860    Cancelled by Driver    CUST1219
#
#       Vehicle Type Pickup Location Drop Location  \
# ...

# %%
#To generate a statistical summary of the data frame (five point summary for numeric columns)
uber_df.describe()
# Out:
#        waiting time     Avg CTAT  Cancelled Rides by Customer  \
# count    994.000000  1004.000000                  1035.000000
# mean       9.315493    13.882171                     0.090821
# std        4.962192     6.408082                     0.287494
# min        1.000000     3.000000                     0.000000
# 25%        4.925000     8.500000                     0.000000
# 50%        9.100000    13.750000                     0.000000
# 75%       13.600000    19.500000                     0.000000
# max       18.000000    25.000000                     1.000000
#
#        Cancelled Rides by Driver  Incomplete Rides  Booking Value  \
# count                1035.000000       1035.000000    1007.000000
# mean                    0.112077          0.069565      40.734955
# std                     0.315614          0.254536      32.685249
# min                     0.000000          0.000000       0.000000
# 25%                     0.000000          0.000000      12.300000
# ...

# %%
#To generate a descriptive summary for categorical columns (objects)
uber_df.describe(include='object')
# Out:
#               Date      Time Booking ID Booking Status Customer ID  \
# count         1035      1035       1035           1035        1014
# unique         181       722        986              4         245
# top     2025-01-24  13:35:00  UBR100804      Completed    CUST1083
# freq            12         5          2            753          11
#
#        Vehicle Type Pickup Location Drop Location  \
# count          1020            1019          1020
# unique            5              20            20
# top          UberXL         Toronto        London
# freq            221              67            63
#
#        Reason for cancelling by Customer Driver Cancellation Reason  \
# count                                 94                        116
# unique                                 5                          5
# top               Driver taking too long         Personal emergency
# freq                                  26                         27
#
# ...
